# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
summary = pd.read_excel('Tables/2. 2016-2020 Consumption by week_USC CONFIDENTIAL.xlsx')
summary
# Out:
#     CONFIDENTIAL Contains Proprietary Information Unnamed: 1  \
# 0                                             NaN      Index
# 1                                             NaN          1
# 2                                             NaN          2
# 3                                             NaN          3
# 4                                             NaN          4
# ..                                            ...        ...
# 61                                            NaN         61
# 62                                            NaN         62
# 63                                            NaN         63
# 64                                            NaN         64
# 65                                            NaN         65
#
#                                            Unnamed: 2  \
# 0   Report summary for 2016-2020 Consumption by we...
# 1                   2016-2020 Consumption by week_USC
# 2                   2016-2020 Consumption by week_USC
# ...

# %%
sheet_1 = pd.read_excel('Tables/2. 2016-2020 Consumption by week_USC CONFIDENTIAL.xlsx', sheet_name = '1', header = 8)
sheet_1
# Out:
#                              Unnamed: 0  Week Ending 01-11-15  \
# 0                    33 KH DINNER 32 PK                   NaN
# 1        34 KH Orig Dnr 32pk 7343507032                   NaN
# 2                    11 KH DINNER 24 PK          2.453733e+05
# 3        22 KH Orig Dnr 24pk 7343500230          2.416441e+05
# 4    29 KH Svry Btr Dnr 24pk 7343500233          3.729193e+03
# 5                    30 KH DINNER 18 PK          1.998000e+03
# 6        31 KH Orig Dnr 18pk 7343507018          1.519875e+03
# 7                    10 KH DINNER 12 PK          8.763390e+05
# 8        19 KH Orig Dnr 12pk 7343500004          6.349654e+05
# 9    21 KH Svry Btr Dnr 12pk 7343500201          1.695519e+05
# 10    20 KH Hny Wht Dnr 12pk 7343500005          7.182161e+04
# 11                    09 KH DINNER 4 PK          1.807465e+05
# 12        16 KH Orig Dnr 4pk 7343500006          1.661325e+05
# 13    18 KH Svry Btr Dnr 4pk 7343500225          7.047072e+03
# ...

# %%
type(sheet_1['Week Ending 01-11-15'][3])
# Out:
# numpy.float64

# %%
sheet_1.rename(columns={'Unnamed: 0': 'Product'}, inplace = True)
sheet_1.head()
# Out:
#                               Product  Week Ending 01-11-15  \
# 0                  33 KH DINNER 32 PK                   NaN
# 1      34 KH Orig Dnr 32pk 7343507032                   NaN
# 2                  11 KH DINNER 24 PK         245373.288047
# 3      22 KH Orig Dnr 24pk 7343500230         241644.094664
# 4  29 KH Svry Btr Dnr 24pk 7343500233           3729.193383
#
#    Week Ending 01-18-15  Week Ending 01-25-15  Week Ending 02-01-15  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2         247372.076642         230058.028684         273032.680683
# 3         244973.025857         228546.849209         271995.932698
# 4           2399.050786           1511.179475           1036.747985
#
#    Week Ending 02-08-15  Week Ending 02-15-15  Week Ending 02-22-15  \
# 0                   NaN                   NaN                   NaN
# ...

# %%
melt_sheet1 = pd.melt(sheet_1, 
                      id_vars = ['Product'], 
                      var_name = 'Week',
                      value_name = 'Consumption')
melt_sheet1.head()
# Out:
#                               Product                  Week    Consumption
# 0                  33 KH DINNER 32 PK  Week Ending 01-11-15            NaN
# 1      34 KH Orig Dnr 32pk 7343507032  Week Ending 01-11-15            NaN
# 2                  11 KH DINNER 24 PK  Week Ending 01-11-15  245373.288047
# 3      22 KH Orig Dnr 24pk 7343500230  Week Ending 01-11-15  241644.094664
# 4  29 KH Svry Btr Dnr 24pk 7343500233  Week Ending 01-11-15    3729.193383

# %%
melt_sheet1['SKU'] = 'Total US'
melt_sheet1.head()
# Out:
#                               Product                  Week    Consumption  \
# 0                  33 KH DINNER 32 PK  Week Ending 01-11-15            NaN
# 1      34 KH Orig Dnr 32pk 7343507032  Week Ending 01-11-15            NaN
# 2                  11 KH DINNER 24 PK  Week Ending 01-11-15  245373.288047
# 3      22 KH Orig Dnr 24pk 7343500230  Week Ending 01-11-15  241644.094664
# 4  29 KH Svry Btr Dnr 24pk 7343500233  Week Ending 01-11-15    3729.193383
#
#         SKU
# 0  Total US
# 1  Total US
# 2  Total US
# 3  Total US
# 4  Total US

# %%
concat_df = pd.DataFrame()

for i in range(1,66):
    sheet = pd.read_excel('Tables/2. 2016-2020 Consumption by week_USC CONFIDENTIAL.xlsx', sheet_name = i, header = 8).\
                    rename(columns={'Unnamed: 0': 'Product'})
    melt_sheet = pd.melt(sheet, 
                      id_vars = ['Product'], 
                      var_name = 'Week Ending',
                      value_name = 'Consumption')
    melt_sheet['SKU'] = summary.loc[i,'Unnamed: 3']
    concat_df = pd.concat([concat_df, melt_sheet], axis = 0, ignore_index = True)

# %%
concat_df.shape
# Out:
# (403623, 4)

# %%
concat_df = concat_df.fillna(0)
concat_df['Week Ending'] = concat_df['Week Ending'].str.extract('(\d+-\d+-\d+)')
concat_df.head()
# Out:
#                               Product Week Ending    Consumption  \
# 0                  33 KH DINNER 32 PK    01-11-15       0.000000
# 1      34 KH Orig Dnr 32pk 7343507032    01-11-15       0.000000
# 2                  11 KH DINNER 24 PK    01-11-15  245373.288047
# 3      22 KH Orig Dnr 24pk 7343500230    01-11-15  241644.094664
# 4  29 KH Svry Btr Dnr 24pk 7343500233    01-11-15    3729.193383
#
#                        SKU
# 0  Total US - Multi Outlet
# 1  Total US - Multi Outlet
# 2  Total US - Multi Outlet
# 3  Total US - Multi Outlet
# 4  Total US - Multi Outlet

# %%
concat_df['Week Ending'] = pd.to_datetime(concat_df['Week Ending'])
concat_df.head()
# Out:
#                               Product Week Ending    Consumption  \
# 0                  33 KH DINNER 32 PK  2015-01-11       0.000000
# 1      34 KH Orig Dnr 32pk 7343507032  2015-01-11       0.000000
# 2                  11 KH DINNER 24 PK  2015-01-11  245373.288047
# 3      22 KH Orig Dnr 24pk 7343500230  2015-01-11  241644.094664
# 4  29 KH Svry Btr Dnr 24pk 7343500233  2015-01-11    3729.193383
#
#                        SKU
# 0  Total US - Multi Outlet
# 1  Total US - Multi Outlet
# 2  Total US - Multi Outlet
# 3  Total US - Multi Outlet
# 4  Total US - Multi Outlet

# %%
concat_df['SKU'] = concat_df['SKU'].str.replace(' - Multi Outlet', '')
concat_df.head()
# Out:
#                               Product Week Ending    Consumption       SKU
# 0                  33 KH DINNER 32 PK  2015-01-11       0.000000  Total US
# 1      34 KH Orig Dnr 32pk 7343507032  2015-01-11       0.000000  Total US
# 2                  11 KH DINNER 24 PK  2015-01-11  245373.288047  Total US
# 3      22 KH Orig Dnr 24pk 7343500230  2015-01-11  241644.094664  Total US
# 4  29 KH Svry Btr Dnr 24pk 7343500233  2015-01-11    3729.193383  Total US

# %%
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403623 entries, 0 to 403622
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Product      403623 non-null  object
#  1   Week Ending  403623 non-null  datetime64[ns]
#  2   Consumption  403623 non-null  float64
#  3   SKU          403623 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 12.3+ MB

# %%
concat_df['SKU'].unique()
# Out:
# array(['Total US', 'Albany, NY', 'Atlanta, GA',
#        'Baltimore, MD/Washington D.C.', 'Birmingham/Montgomery, AL',
#        'Boise, ID', 'Boston, MA', 'Buffalo/Rochester, NY',
#        'Charlotte, NC', 'Chicago, IL', 'Cincinnati/Dayton, OH',
#        'Cleveland, OH', 'Columbus, OH', 'Dallas/Ft. Worth, TX',
#        'Denver, CO', 'Des Moines, IA', 'Detroit, MI', 'Grand Rapids, MI',
#        'Green Bay, WI', 'Harrisburg/Scranton, PA',
#        'Hartford, CT/Springfield, MA', 'Houston, TX', 'Indianapolis, IN',
#        'Jacksonville, FL', 'Kansas City, KS', 'Knoxville, TN',
#        'Las Vegas, NV', 'Little Rock, AR', 'Los Angeles, CA',
#        'Louisville, KY', 'Memphis, TN', 'Miami/Ft. Lauderdale, FL',
#        'Milwaukee, WI', 'Minneapolis/St. Paul, MN', 'Mississippi',
#        'Nashville, TN', 'New England', 'New Orleans, LA/Mobile, AL',
#        'New York, NY', 'Oklahoma City, OK', 'Omaha, NE', 'Orlando, FL',
# ...

# %%
US_consumption = concat_df[concat_df['SKU']=='Total US']

plt.figure(figsize = (20,10))

sns.lineplot(data = US_consumption,
             x = 'Week Ending',
             y = 'Consumption',
             hue = 'Product')

# %%
plt.figure(figsize = (20,10))
US_consumption.groupby('Product')['Consumption'].sum().plot(kind = 'bar')

# %%
concat_df.to_csv('merged_data.csv')

# %%
concat_df.head()
# Out:
#                               Product Week Ending    Consumption       SKU
# 0                  33 KH DINNER 32 PK  2015-01-11       0.000000  Total US
# 1      34 KH Orig Dnr 32pk 7343507032  2015-01-11       0.000000  Total US
# 2                  11 KH DINNER 24 PK  2015-01-11  245373.288047  Total US
# 3      22 KH Orig Dnr 24pk 7343500230  2015-01-11  241644.094664  Total US
# 4  29 KH Svry Btr Dnr 24pk 7343500233  2015-01-11    3729.193383  Total US

# %%
total = concat_df.loc[concat_df['Product'] == "04 Total King's Hawaiian"]

# %%
US = total.loc[concat_df['SKU'] == "Total US"]

# %%
data = US.loc[concat_df['Week Ending'] < '2016-01-01'].reset_index(drop = True)

# %%
data = data.assign(TV = np.nan)
data
# Out:
#                      Product Week Ending   Consumption       SKU  TV
# 0   04 Total King's Hawaiian  2015-01-11  1.633053e+06  Total US NaN
# 1   04 Total King's Hawaiian  2015-01-18  1.621815e+06  Total US NaN
# 2   04 Total King's Hawaiian  2015-01-25  1.568003e+06  Total US NaN
# 3   04 Total King's Hawaiian  2015-02-01  1.951725e+06  Total US NaN
# 4   04 Total King's Hawaiian  2015-02-08  1.770868e+06  Total US NaN
# 5   04 Total King's Hawaiian  2015-02-15  1.713693e+06  Total US NaN
# 6   04 Total King's Hawaiian  2015-02-22  1.700801e+06  Total US NaN
# 7   04 Total King's Hawaiian  2015-03-01  1.658889e+06  Total US NaN
# 8   04 Total King's Hawaiian  2015-03-08  1.699894e+06  Total US NaN
# 9   04 Total King's Hawaiian  2015-03-15  1.705637e+06  Total US NaN
# 10  04 Total King's Hawaiian  2015-03-22  1.698304e+06  Total US NaN
# 11  04 Total King's Hawaiian  2015-03-29  1.792756e+06  Total US NaN
# 12  04 Total King's Hawaiian  2015-04-05  3.616990e+06  Total US NaN
# ...

# %%
# Binary for TV
data.loc[(data['Week Ending'] >= '2015-01-04') & (data['Week Ending'] < '2015-04-12'), 'TV'] = 1
data.loc[(data['Week Ending'] >= '2015-09-06') & (data['Week Ending'] < '2015-12-06'), 'TV'] = 1

# %%
# Binary for 
data.loc[(data['Week Ending'] >= '2015-01-04') & (data['Week Ending'] < '2015-04-12'), 'TV'] = 1
data.loc[(data['Week Ending'] >= '2015-09-06') & (data['Week Ending'] < '2015-12-06'), 'TV'] = 1

# %%
data
# Out:
#                      Product Week Ending   Consumption       SKU   TV
# 0   04 Total King's Hawaiian  2015-01-11  1.633053e+06  Total US  1.0
# 1   04 Total King's Hawaiian  2015-01-18  1.621815e+06  Total US  1.0
# 2   04 Total King's Hawaiian  2015-01-25  1.568003e+06  Total US  1.0
# 3   04 Total King's Hawaiian  2015-02-01  1.951725e+06  Total US  1.0
# 4   04 Total King's Hawaiian  2015-02-08  1.770868e+06  Total US  1.0
# 5   04 Total King's Hawaiian  2015-02-15  1.713693e+06  Total US  1.0
# 6   04 Total King's Hawaiian  2015-02-22  1.700801e+06  Total US  1.0
# 7   04 Total King's Hawaiian  2015-03-01  1.658889e+06  Total US  1.0
# 8   04 Total King's Hawaiian  2015-03-08  1.699894e+06  Total US  1.0
# 9   04 Total King's Hawaiian  2015-03-15  1.705637e+06  Total US  1.0
# 10  04 Total King's Hawaiian  2015-03-22  1.698304e+06  Total US  1.0
# 11  04 Total King's Hawaiian  2015-03-29  1.792756e+06  Total US  1.0
# ...

# %%
data
# Out:
#                      Product Week Ending   Consumption       SKU  \
# 0   04 Total King's Hawaiian  2015-01-11  1.633053e+06  Total US
# 1   04 Total King's Hawaiian  2015-01-18  1.621815e+06  Total US
# 2   04 Total King's Hawaiian  2015-01-25  1.568003e+06  Total US
# 3   04 Total King's Hawaiian  2015-02-01  1.951725e+06  Total US
# 4   04 Total King's Hawaiian  2015-02-08  1.770868e+06  Total US
# 5   04 Total King's Hawaiian  2015-02-15  1.713693e+06  Total US
# 6   04 Total King's Hawaiian  2015-02-22  1.700801e+06  Total US
# 7   04 Total King's Hawaiian  2015-03-01  1.658889e+06  Total US
# 8   04 Total King's Hawaiian  2015-03-08  1.699894e+06  Total US
# 9   04 Total King's Hawaiian  2015-03-15  1.705637e+06  Total US
# 10  04 Total King's Hawaiian  2015-03-22  1.698304e+06  Total US
# 11  04 Total King's Hawaiian  2015-03-29  1.792756e+06  Total US
# 12  04 Total King's Hawaiian  2015-04-05  3.616990e+06  Total US
# ...
