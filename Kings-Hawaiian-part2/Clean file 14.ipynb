# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('Tables/14. Ongoing promos and placement by retailer USC CONFIDENTIAL.xlsx', sheet_name = 'In store placement and promo', header = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119990 entries, 0 to 119989
# Data columns (total 45 columns):
#  #   Column                                               Non-Null Count   Dtype
# ---  ------                                               --------------   -----
#  0   Geography                                            119990 non-null  object
#  1   Product                                              119990 non-null  object
#  2   Platform                                             119990 non-null  object
#  3   WK Start                                             119990 non-null  datetime64[ns]
#  4   Wk End                                               119990 non-null  datetime64[ns]
#  5   Holiday                                              5953 non-null    object
#  6   Chicken Program/Meal Deal                            100505 non-null  object
#  7   Secondary Deli                                       102103 non-null  object
# ...

# %%
data['Chicken Program/Meal Deal'] = data['Chicken Program/Meal Deal'].replace({'No': 0, 'Yes': 1})
data['Secondary Deli'] = data['Secondary Deli'].replace({'No': 0, 'Yes': 1})
data['Secondary Bakery'] = data['Secondary Bakery'].replace({'No': 0, 'Yes': 1})
data['Secondary Center store'] = data['Secondary Center store'].replace({'No': 0, 'Yes': 1})
data['Retail Coverage'] = data['Retail Coverage'].replace({'No': 0, 'Yes ': 1})

# %%
data[['Chicken Program/Meal Deal', 'Secondary Deli', 'Secondary Bakery',
       'Secondary Center store', 'Retail Coverage']].tail()
# Out:
#        Chicken Program/Meal Deal Secondary Deli Secondary Bakery  \
# 119985                       NaN            NaN              NaN
# 119986                       NaN            NaN              NaN
# 119987                       NaN            NaN              NaN
# 119988                       NaN            NaN              NaN
# 119989                       NaN            NaN              NaN
#
#        Secondary Center store  Retail Coverage
# 119985                    NaN              1.0
# 119986                    NaN              1.0
# 119987                    NaN              1.0
# 119988                    NaN              1.0
# 119989                    NaN              1.0

# %%
data = data.fillna(0)

# %%
data.Holiday.unique()
# Out:
# array([0, 'SuperBowl ', 'Easter Week ', 'Memorial Week ', 'July 4th ',
#        'Back to School ', 'Labor Day ', 'Halloween ', 'Thanksgiving ',
#        'Christmas', 'Christmas/NY', 'Easter Weeks'], dtype=object)

# %%
holiday_dummy = pd.get_dummies(data['Holiday'], prefix='Holiday').iloc[:, 1:]
holiday_dummy
# Out:
#         Holiday_Back to School   Holiday_Christmas  Holiday_Christmas/NY  \
# 0                             0                  0                     0
# 1                             0                  0                     0
# 2                             0                  0                     0
# 3                             0                  0                     0
# 4                             0                  0                     0
# ...                         ...                ...                   ...
# 119985                        0                  0                     0
# 119986                        0                  0                     0
# 119987                        0                  0                     0
# 119988                        0                  0                     0
# 119989                        0                  0                     0
#
#         Holiday_Easter Week   Holiday_Easter Weeks  Holiday_Halloween   \
# ...

# %%
In [1108]: df_out = pd.concat([df1, df2], axis=1)

In [1109]: df_out.columns = list(range(len(df_out.columns)))

# %%
data = pd.concat([data, holiday_dummy], axis = 1)
data
# Out:
#                               Geography            Product      Platform  \
# 0       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 1       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 2       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 3       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 4       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# ...                                 ...                ...           ...
# 119985                   KR Smiths Corp    KH 12 CT Butter  Dinner Rolls
# 119986                   KR Smiths Corp  KH 24 CT Original  Dinner Rolls
# 119987                   KR Smiths Corp       KH Mini Subs      Sandwich
# 119988                   KR Smiths Corp    KH 24 CT Butter  Dinner Rolls
# 119989                   KR Smiths Corp     KH Slider Buns      Sandwich
#
#          WK Start     Wk End Holiday Chicken Program/Meal Deal Secondary Deli  \
# ...

# %%
data.drop(['Holiday'], axis = 1)
# Out:
#                               Geography            Product      Platform  \
# 0       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 1       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 2       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 3       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# 4       DeCA Total CONUS-RMA - Military  KH Hamburger Buns      Sandwich
# ...                                 ...                ...           ...
# 119985                   KR Smiths Corp    KH 12 CT Butter  Dinner Rolls
# 119986                   KR Smiths Corp  KH 24 CT Original  Dinner Rolls
# 119987                   KR Smiths Corp       KH Mini Subs      Sandwich
# 119988                   KR Smiths Corp    KH 24 CT Butter  Dinner Rolls
# 119989                   KR Smiths Corp     KH Slider Buns      Sandwich
#
#          WK Start     Wk End Chicken Program/Meal Deal Secondary Deli  \
# ...

# %%
data.to_csv('14. Ongoing_promos_placement_by_retailer Cleaned.csv')
